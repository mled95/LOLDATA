# %%
from riotwatcher import LolWatcher, ApiError

lol_watcher = LolWatcher('<your-api-key>')

my_region = 'na1'

me = lol_watcher.summoner.by_name(my_region, 'pseudonym117')
print(me)

# all objects are returned (by default) as a dict
# lets see if i got diamond yet (i probably didnt)
my_ranked_stats = lol_watcher.league.by_summoner(my_region, me['id'])
print(my_ranked_stats)

# First we get the latest version of the game from data dragon
versions = lol_watcher.data_dragon.versions_for_region(my_region)
champions_version = versions['n']['champion']

# Lets get some champions
current_champ_list = lol_watcher.data_dragon.champions(champions_version)
print(current_champ_list)

# For Riot's API, the 404 status code indicates that the requested data wasn't found and
# should be expected to occur in normal operation, as in the case of a an
# invalid summoner name, match ID, etc.
#
# The 429 status code indicates that the user has sent too many requests
# in a given amount of time ("rate limiting").

try:
    response = lol_watcher.summoner.by_name(my_region, 'this_is_probably_not_anyones_summoner_name')
except ApiError as err:
    if err.response.status_code == 429:
        print('We should retry in {} seconds.'.format(err.response.headers['Retry-After']))
        print('this retry-after is handled by default by the RiotWatcher library')
        print('future requests wait until the retry-after time passes')
    elif err.response.status_code == 404:
        print('Summoner with that ridiculous name not found.')
    else:
        raise

lol_watcher = LolWatcher('<your-api-key>')

my_region = 'na1'

me = lol_watcher.summoner.by_name(my_region, 'pseudonym117')
print(me)

# all objects are returned (by default) as a dict
# lets see if i got diamond yet (i probably didnt)
my_ranked_stats = lol_watcher.league.by_summoner(my_region, me['id'])
print(my_ranked_stats)

# First we get the latest version of the game from data dragon
versions = lol_watcher.data_dragon.versions_for_region(my_region)
champions_version = versions['n']['champion']

# Lets get some champions
current_champ_list = lol_watcher.data_dragon.champions(champions_version)
print(current_champ_list)

# For Riot's API, the 404 status code indicates that the requested data wasn't found and
# should be expected to occur in normal operation, as in the case of a an
# invalid summoner name, match ID, etc.
#
# The 429 status code indicates that the user has sent too many requests
# in a given amount of time ("rate limiting").

try:
    response = lol_watcher.summoner.by_name(my_region, 'this_is_probably_not_anyones_summoner_name')
except ApiError as err:
    if err.response.status_code == 429:
        print('We should retry in {} seconds.'.format(err.response.headers['Retry-After']))
        print('this retry-after is handled by default by the RiotWatcher library')
        print('future requests wait until the retry-after time passes')
    elif err.response.status_code == 404:
        print('Summoner with that ridiculous name not found.')
    else:
        raise
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-6a6dcd223f53> in <module>
# ----> 1 from riotwatcher import LolWatcher, ApiError
#       2
#       3 lol_watcher = LolWatcher('<your-api-key>')
#       4
#       5 my_region = 'na1'
#
# ModuleNotFoundError: No module named 'riotwatcher'

# %%
# !pip install riotwatcher
# Out:
# ...
#      |████████████████████████████████| 53 kB 748 kB/s eta 0:00:01
# ...

# %%
from riotwatcher import LolWatcher, ApiError

apik = 'RGAPI-7ffac6ab-2edf-4a61-a253-573614ec4816'

lol_watcher = LolWatcher(apik)

my_region = 'na1'

me = lol_watcher.summoner.by_name(my_region, 'Long live duck')
print(me)

# all objects are returned (by default) as a dict
# lets see if i got diamond yet (i probably didnt)
my_ranked_stats = lol_watcher.league.by_summoner(my_region, me['id'])
print(my_ranked_stats)

# First we get the latest version of the game from data dragon
versions = lol_watcher.data_dragon.versions_for_region(my_region)
champions_version = versions['n']['champion']

# Lets get some champions
current_champ_list = lol_watcher.data_dragon.champions(champions_version)
print(current_champ_list)

# For Riot's API, the 404 status code indicates that the requested data wasn't found and
# should be expected to occur in normal operation, as in the case of a an
# invalid summoner name, match ID, etc.
#
# The 429 status code indicates that the user has sent too many requests
# in a given amount of time ("rate limiting").

try:
    response = lol_watcher.summoner.by_name(my_region, 'this_is_probably_not_anyones_summoner_name')
except ApiError as err:
    if err.response.status_code == 429:
        print('We should retry in {} seconds.'.format(err.response.headers['Retry-After']))
        print('this retry-after is handled by default by the RiotWatcher library')
        print('future requests wait until the retry-after time passes')
    elif err.response.status_code == 404:
        print('Summoner with that ridiculous name not found.')
    else:
        raise

lol_watcher = LolWatcher(apik)

my_region = 'na1'

me = lol_watcher.summoner.by_name(my_region, 'long live duck')
print(me)

# all objects are returned (by default) as a dict
# lets see if i got diamond yet (i probably didnt)
my_ranked_stats = lol_watcher.league.by_summoner(my_region, me['id'])
print(my_ranked_stats)

# First we get the latest version of the game from data dragon
versions = lol_watcher.data_dragon.versions_for_region(my_region)
champions_version = versions['n']['champion']

# Lets get some champions
current_champ_list = lol_watcher.data_dragon.champions(champions_version)
print(current_champ_list)

# For Riot's API, the 404 status code indicates that the requested data wasn't found and
# should be expected to occur in normal operation, as in the case of a an
# invalid summoner name, match ID, etc.
#
# The 429 status code indicates that the user has sent too many requests
# in a given amount of time ("rate limiting").

try:
    response = lol_watcher.summoner.by_name(my_region, 'this_is_probably_not_anyones_summoner_name')
except ApiError as err:
    if err.response.status_code == 429:
        print('We should retry in {} seconds.'.format(err.response.headers['Retry-After']))
        print('this retry-after is handled by default by the RiotWatcher library')
        print('future requests wait until the retry-after time passes')
    elif err.response.status_code == 404:
        print('Summoner with that ridiculous name not found.')
    else:
        raise
# Out:
# {'id': 'nnHpuixwU-pimyd-LzEPa14h-ePHF2GWakyU_V4c8d6s9Ss', 'accountId': '814WqyOf3reWWEP5Qxd4AFTp6AXAGTm1Jzd0KAbRBjHRqhs', 'puuid': '5vXyb11K46SKmnavDBjM4ee9UTxv58j7bDPElOmCQXvtTCQn3jVODg9Br1hYzibQ3MwvoVmFrAjxVA', 'name': 'Long Live Duck', 'profileIconId': 1667, 'revisionDate': 1617149109000, 'summonerLevel': 425}
# ...

# %%
apik = 'RGAPI-7ffac6ab-2edf-4a61-a253-573614ec4816'
key = apik
watcher = LolWatcher(key)

def printStats(summonerName):
    summoner = watcher.summoner.by_name('na1', summonerName)
    stats = watcher.league.by_summoner('na1', summoner['id'])
    
    tier = stats[0]['tier']
    rank = stats[0]['rank']
    
    
    
    print(tier, rank)

# %%
def Matches(summonerName):
    summoner = watcher.summoner.by_name('na1', summonerName)
    stats = watcher.league.by_summoner('na1', summoner['id'])
    
    tier = stats[0]['tier']
    rank = stats[0]['rank']
    
    matchBlock = watcher.match.matchlist_by_account('na1','814WqyOf3reWWEP5Qxd4AFTp6AXAGTm1Jzd0KAbRBjHRqhs')
    mb = matchBlock['matches']
    dd = []
    riri = []
    for i in mb:
        dd.append(i['gameId'])
        
    print(dd)

# %%
matchBlock = watcher.match.matchlist_by_account('na1','814WqyOf3reWWEP5Qxd4AFTp6AXAGTm1Jzd0KAbRBjHRqhs')
mb = matchBlock['matches']
riri = []
for i in mb:
    if(i['champion']==92):
        riri.append(i['gameId'])
riri
# Out:
# [3855809203,
#  3855840613,
#  3853445222,
#  3853470122,
#  3853420194,
#  3847040993,
#  3846826336,
#  3846801482,
#  3846578262,
#  3846115631,
#  3845975940,
#  3845676403,
#  3845617879,
#  3845545488,
#  3845582655,
#  3845524181,
#  3844568825,
#  3844385356,
#  3844103069,
#  3843571692,
#  3842645176,
#  3842528237,
#  3841783386,
#  3841651141,
#  3840938110,
#  3840916089,
#  3840851921,
#  3840498748,
#  3840516408,
#  3839700508,
#  3839608364,
#  3839581833,
#  3839505880,
#  3839413580,
#  3839351976,
#  3839219333,
#  3839168893,
#  3839194806,
#  3839170979,
#  3839094328,
#  3838187921,
#  3837931104,
#  3837858716,
#  3837155309,
#  3836948018,
#  3836963126,
#  3836809298,
#  3836806098,
#  3836803984,
#  3836757026,
#  3836665908,
#  3836546555,
#  3836490214,
#  3835544250,
#  3834074850,
#  3833086628,
#  3832405715,
#  3832390341,
#  3832345151,
#  3832226254,
#  3832123888,
#  3830770419,
#  3830430689,
#  3830064881,
#  3830061812,
#  3830003497,
# ...

# %%
type(riri)
# Out:
# list

# %%
def matchListPull(summonerName):
    matchBlock = watcher.match.matchlist_by_account('na1','814WqyOf3reWWEP5Qxd4AFTp6AXAGTm1Jzd0KAbRBjHRqhs')
    #gameIds = matchBlock['matches'][i]['gameId']
    
    
    
    for i in matchBlock:
        crf = matchBlock[i][i]#['matches'][i]
        df.append(crf)
    
    
    print(df)
# as a default, the print() method also contains end,
# ending the function

# %%
printStats('long live duck')
# Out:
# SILVER IV

# %%
matchListPull('long live duck')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-bcce78e53c14> in <module>
# ----> 1 matchListPull('long live duck')
#
# <ipython-input-55-15a7f5c7996c> in matchListPull(summonerName)
#       6
#       7     for i in matchBlock:
# ----> 8         crf = matchBlock[i][i]#['matches'][i]
#       9         df.append(crf)
#      10
#
# TypeError: list indices must be integers or slices, not str

# %%
gameIdList = Matches('long live duck')
# Out:
# [3855809203, 3855840613, 3854594777, 3853419646, 3853445222, 3853470122, 3853420194, 3847161143, 3847083735, 3847040993, 3846826336, 3846801482, 3846639530, 3846578262, 3846115631, 3845975940, 3845676403, 3845671423, 3845617879, 3845545488, 3845582655, 3845524181, 3844568825, 3844485558, 3844410697, 3844385356, 3844103069, 3843855686, 3843571692, 3842645176, 3842528237, 3841783386, 3841651141, 3840938110, 3840916089, 3840846644, 3840851921, 3840498748, 3840516408, 3839700508, 3839608364, 3839581833, 3839505880, 3839413580, 3839351976, 3839219333, 3839168893, 3839194806, 3839170979, 3839094328, 3838187921, 3837931104, 3837858716, 3837155309, 3836948018, 3836963126, 3836809298, 3836806098, 3836803984, 3836757026, 3836665908, 3836546555, 3836490214, 3835544250, 3834074850, 3833170361, 3833086628, 3832405715, 3832390341, 3832345151, 3832226254, 3832123888, 3832037305, 3830770419, 3830430689, 3830064881, 3830061812, 3830003497, 3829282515, 3828585458, 3828580280, 3828024244, 3828030308, 3
# ...

# %%
type(gameIdList)
# Out:
# NoneType

# %%
gameIdListt = [3855809203, 3855840613, 3854594777, 3853419646, 3853445222, 3853470122, 3853420194, 3847161143, 3847083735, 3847040993, 3846826336, 3846801482, 3846639530, 3846578262, 3846115631, 3845975940, 3845676403, 3845671423, 3845617879, 3845545488, 3845582655, 3845524181, 3844568825, 3844485558, 3844410697, 3844385356, 3844103069, 3843855686, 3843571692, 3842645176, 3842528237, 3841783386, 3841651141, 3840938110, 3840916089, 3840846644, 3840851921, 3840498748, 3840516408, 3839700508, 3839608364, 3839581833, 3839505880, 3839413580, 3839351976, 3839219333, 3839168893, 3839194806, 3839170979, 3839094328, 3838187921, 3837931104, 3837858716, 3837155309, 3836948018, 3836963126, 3836809298, 3836806098, 3836803984, 3836757026, 3836665908, 3836546555, 3836490214, 3835544250, 3834074850, 3833170361, 3833086628, 3832405715, 3832390341, 3832345151, 3832226254, 3832123888, 3832037305, 3830770419, 3830430689, 3830064881, 3830061812, 3830003497, 3829282515, 3828585458, 3828580280, 3828024244, 3828030308, 3827957063, 3827773406, 3827695308, 3827526941, 3826656381, 3824279092, 3824254585, 3823855498, 3823787983, 3823784117, 3823556892, 3823526331, 3823540660, 3823466568, 3823438909, 3823424992, 3822024596]

len(gameIdListt)
range(len(gameIdListt))
# Out:
# range(0, 100)

# %%
matchData = matchData0['participants']
matchData0 = watcher.match.by_id('na1', '3855809203')
init = []
for i in matchData:
    
    print(i['participantId'], i['championId'],i['stats']['win'],
         i['stats']['kills'], i['stats']['deaths'],
         i['stats']['longestTimeSpentLiving'], i['stats']['visionScore'],
         i['stats']['firstBloodKill'],i['stats']['firstTowerKill'],
         i['stats']['timeCCingOthers'], i['stats']['totalDamageDealtToChampions'],
         i['stats']['firstInhibitorKill'],
          i['teamId']
         
         )
# Out:
# 1 21 False 7 4 791 16 False False 6 20792 False 100
# 2 234 False 4 10 387 13 False False 20 12370 False 100
# 3 117 False 0 7 707 22 False False 29 6778 False 100
# 4 92 False 4 5 503 8 False False 25 10622 False 100
# 5 55 False 4 5 801 25 False False 0 13902 False 100
# 6 106 True 4 4 510 27 False True 27 14289 False 200
# 7 236 True 7 2 1158 12 False False 0 14405 False 200
# 8 35 True 6 3 869 19 False False 16 12844 False 200
# 9 131 True 12 4 619 15 True False 10 33354 True 200
# 10 89 True 2 6 759 38 False False 42 7005 False 200

# %%
def matchCompiler():
    
    for i in riri:
    
        cx = watcher.match.by_id('na1', i)
        
        for j in range(len(cx['participants'])):
            
            if(cx['participants'][j]['championId']==92):
                print(i,cx['participants'][j]['timeline']['lane'] ,cx['participants'][j]['participantId'], cx['participants'][j]['championId'],
                     cx['participants'][j]['stats']['win'],matchData[j]['stats']['firstBloodKill'],
                     matchData[j]['stats']['firstInhibitorKill'],matchData[j]['stats']['inhibitorKills'], matchData[j]['stats']['visionWardsBoughtInGame'],
                      matchData[j]['stats']['visionScore'],
                      matchData[j]['stats']['item0'], matchData[j]['stats']['item1'], matchData[j]['stats']['kills'],
                      matchData[j]['stats']['deaths'], matchData[j]['stats']['assists'],  (matchData[j]['stats']['kills'] + matchData[j]['stats']['assists'])/matchData[j]['stats']['deaths'],
                      matchData[j]['stats']['longestTimeSpentLiving']
                      
                     )
            
       
    
matchCompiler()
# Out:
# 3855809203 TOP 4 92 False False False 0 2 8 3074 6630 4 5 3 1.4 503
# 3855840613 NONE 4 92 False False False 0 2 8 3074 6630 4 5 3 1.4 503
# 3853445222 TOP 5 92 False False False 0 2 25 1055 3115 4 5 7 2.2 801
# 3853470122 TOP 2 92 False False False 0 0 13 3153 6672 4 10 6 1.0 387
# 3853420194 TOP 1 92 True False False 0 1 16 1038 6671 7 4 2 2.25 791
# 3847040993 TOP 5 92 False False False 0 2 25 1055 3115 4 5 7 2.2 801
# 3846826336 TOP 9 92 False True True 1 0 15 3157 4636 12 4 8 5.0 619
# 3846801482 TOP 8 92 False False False 0 0 19 3508 6671 6 3 9 5.0 869
# 3846578262 TOP 5 92 False False False 0 2 25 1055 3115 4 5 7 2.2 801
# 3846115631 TOP 8 92 True False False 0 0 19 3508 6671 6 3 9 5.0 869
# 3845975940 TOP 5 92 False False False 0 2 25 1055 3115 4 5 7 2.2 801
# 3845676403 TOP 8 92 True False False 0 0 19 3508 6671 6 3 9 5.0 869
# 3845617879 NONE 7 92 True False False 0 0 12 1055 6672 7 2 3 5.0 1158
# ...

# %%
def matchCompiler():
    
    for i in gameIdListt:
    
        cx = watcher.match.by_id('na1', i)
        for j in range(len(gameIdListt)):
            print(i, cx['participants'][j]['participantId'], cx['participants'][j]['championId'],
                 cx['participants'][j]['stats']['win'])
            
       
    
matchCompiler()
# Out:
# 3855809203 1 21 False
# 3855809203 2 234 False
# 3855809203 3 117 False
# 3855809203 4 92 False
# 3855809203 5 55 False
# 3855809203 6 106 True
# 3855809203 7 236 True
# 3855809203 8 35 True
# 3855809203 9 131 True
# 3855809203 10 89 True
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-194-ae39052084c8> in <module>
#      10
#      11
# ---> 12 matchCompiler()
#
# <ipython-input-194-ae39052084c8> in matchCompiler()
#       5         cx = watcher.match.by_id('na1', i)
#       6         for j in range(len(gameIdListt)):
# ----> 7             print(i, cx['participants'][j]['participantId'], cx['participants'][j]['championId'],
#       8                  cx['participants'][j]['stats']['win'])
#       9             f=+1
#
# IndexError: list index out of range

# %%
cx = watcher.match.by_id('na1',3855809203 )
cx['participants']['championId']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-173-f0de9a6f0239> in <module>
#       1 cx = watcher.match.by_id('na1',3855809203 )
# ----> 2 cx['participants']['championId']
#
# TypeError: list indices must be integers or slices, not str

# %%
df[0]
# Out:
# [{'platformId': 'NA1',
#   'gameId': 3855809203,
#   'champion': 92,
#   'queue': 420,
#   'season': 13,
#   'timestamp': 1617696541370,
#   'role': 'SOLO',
#   'lane': 'TOP'},
#  {'platformId': 'NA1',
#   'gameId': 3855840613,
#   'champion': 92,
#   'queue': 420,
#   'season': 13,
#   'timestamp': 1617692149112,
#   'role': 'DUO',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3854594777,
#   'champion': 8,
#   'queue': 420,
#   'season': 13,
#   'timestamp': 1617607476407,
#   'role': 'SOLO',
#   'lane': 'MID'},
#  {'platformId': 'NA1',
#   'gameId': 3853419646,
#   'champion': 234,
#   'queue': 420,
#   'season': 13,
#   'timestamp': 1617545045896,
#   'role': 'NONE',
#   'lane': 'JUNGLE'},
#  {'platformId': 'NA1',
#   'gameId': 3853445222,
#   'champion': 92,
#   'queue': 420,
#   'season': 13,
#   'timestamp': 1617541660089,
#   'role': 'SOLO',
#   'lane': 'TOP'},
#  {'platformId': 'NA1',
#   'gameId': 3853470122,
#   'champion': 92,
#   'queue': 420,
# ...

# %%
import pandas as pd
import numpy as np

matchData0 = watcher.match.by_id('na1', '3855809203')

gameData = []

matchData0['participants'][1]['timeline']['lane']
matchData0
# Out:
# {'gameId': 3855809203,
#  'platformId': 'NA1',
#  'gameCreation': 1617696541370,
#  'gameDuration': 1905,
#  'queueId': 420,
#  'mapId': 11,
#  'seasonId': 13,
#  'gameVersion': '11.7.366.7612',
#  'gameMode': 'CLASSIC',
#  'gameType': 'MATCHED_GAME',
#  'teams': [{'teamId': 100,
#    'win': 'Fail',
#    'firstBlood': False,
#    'firstTower': False,
#    'firstInhibitor': False,
#    'firstBaron': False,
#    'firstDragon': False,
#    'firstRiftHerald': False,
#    'towerKills': 2,
#    'inhibitorKills': 0,
#    'baronKills': 0,
#    'dragonKills': 0,
#    'vilemawKills': 0,
#    'riftHeraldKills': 0,
#    'dominionVictoryScore': 0,
#    'bans': [{'championId': 121, 'pickTurn': 1},
#     {'championId': 120, 'pickTurn': 2},
#     {'championId': 777, 'pickTurn': 3},
#     {'championId': 28, 'pickTurn': 4},
#     {'championId': 53, 'pickTurn': 5}]},
#   {'teamId': 200,
#    'win': 'Win',
#    'firstBlood': True,
#    'firstTower': True,
#    'firstInhibitor': True,
# ...

# %%
matchData = matchData0['participants']
matchData0 = watcher.match.by_id('na1', '3855809203')
init = []
for i in matchData:
    
    print(i['participantId'], i['championId'],i['stats']['win'],
         i['stats']['kills'], i['stats']['deaths'],
         i['stats']['longestTimeSpentLiving'], i['stats']['visionScore'],
         i['stats']['firstBloodKill'],i['stats']['firstTowerKill'],
         i['stats']['timeCCingOthers'], i['stats']['totalDamageDealtToChampions'],
         i['stats']['firstInhibitorKill'], i['stats']['inhibitorkills']
          i['teamId']
         
         )
# Out:
# 1 21 False 7 4 791 16 False False 6 20792 False 100
# 2 234 False 4 10 387 13 False False 20 12370 False 100
# 3 117 False 0 7 707 22 False False 29 6778 False 100
# 4 92 False 4 5 503 8 False False 25 10622 False 100
# 5 55 False 4 5 801 25 False False 0 13902 False 100
# 6 106 True 4 4 510 27 False True 27 14289 False 200
# 7 236 True 7 2 1158 12 False False 0 14405 False 200
# 8 35 True 6 3 869 19 False False 16 12844 False 200
# 9 131 True 12 4 619 15 True False 10 33354 True 200
# 10 89 True 2 6 759 38 False False 42 7005 False 200
